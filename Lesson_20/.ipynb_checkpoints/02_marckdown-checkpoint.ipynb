# %% [markdown]
# Звичайний текст

# %% [markdown]
# # Рівень 1
# ## Рівень 2
# ### Рівень 3
# #### Рівень 4
# ##### Рівень 5

# %% [markdown]
# * Не нумерований список 1
# * Не нумерований список 2
#     * Не нумерований список 1.1
#     * Не нумерований список 1.2

# %% [markdown]
# 1. Нумерований список
# 2. Нумерований список
#     1.1. Нумерований список
#     1.2. Нумерований список

# %% [markdown]
# *Текст*
# **Текст**
# _Текст_

# %% [markdown]
# Звичайний текст `Відмітка` звичайний текст

# %% [markdown]
# >Весь абзац - цитата
# звичайний текст

# %% [markdown]
# [Назва посилання](https://github.com/)

# %% [markdown]
# ![Screenshot_1.png](attachment:Screenshot_1.png)

# %% [markdown]
# Зображення додаються так: ![githab](data:image/png;base64,...)

# %%
from IPython.display import IFrame
IFrame('https://www.youtube.com/embed/Wd8XpxN_iJw', 800, 600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://www.youtube.com/embed/Wd8XpxN_iJw"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ***

# %% [markdown]
# | Syntax    | Description | Test Text  |
# | :----     | :----       | :---       |
# | Header    | Title       | Here's this|
# | Paragraph | Text        | Add more   |

# %%
# %%html
#
# <table class="table table-sm">
#   <thead>
#     <tr>
#       <th scope="col">#</th>
#       <th scope="col">First</th>
#       <th scope="col">Last</th>
#       <th scope="col">Handle</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th scope="row">1</th>
#       <td>Mark</td>
#       <td>Otto</td>
#       <td>@mdo</td>
#     </tr>
#     <tr>
#       <th scope="row">2</th>
#       <td>Jacob</td>
#       <td>Thornton</td>
#       <td>@fat</td>
#     </tr>
#     <tr>
#       <th scope="row">3</th>
#       <td colspan="2">Larry the Bird</td>
#       <td>@twitter</td>
#     </tr>
#   </tbody>
# </table>
# Out:
# <table class="table table-sm">
#   <thead>
#     <tr>
#       <th scope="col">#</th>
#       <th scope="col">First</th>
#       <th scope="col">Last</th>
#       <th scope="col">Handle</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th scope="row">1</th>
#       <td>Mark</td>
#       <td>Otto</td>
#       <td>@mdo</td>
#     </tr>
#     <tr>
#       <th scope="row">2</th>
#       <td>Jacob</td>
#       <td>Thornton</td>
#       <td>@fat</td>
#     </tr>
#     <tr>
#       <th scope="row">3</th>
#       <td colspan="2">Larry the Bird</td>
#       <td>@twitter</td>
#     </tr>
#   </tbody>
# </table>
